# %%
a=int(input("enter value of a"))
b=int(input("enter value of b"))
c=int(input("entervalue of c"))
if(a>b)&(a>c):
   largest=a
elif(b>a)&(b>c):
    largest=b
elif(c>a)&(c>b):
    largest=c
print(largest)
# Out:
# enter value of a1
# enter value of b2
# entervalue of c3
# 3

# %%
a=int(input("enter value of a"))
b=int(input("enter value of b"))
if(a==b):
   print("both are equal")
else:
    print("not equal")
# Out:
# enter value of a1
# enter value of b1
# both are equal

# %%
mo=int(input("enter marksobtained"))
pm=35
if(mo>pm):
    print("pass")
else:
      print("fail")
# Out:
# enter marksobtained40
# pass

# %%
a,b=(5,6)
if ((a+b)>5):
    print("sum is greater than 5",a+b)
else:
    print("sum is lesser than 5",a+b)
# Out:
# sum is greater than 5 11

# %%
a=int(input("enter a"))
b=int(input("enter b"))
c=int(input("enter c"))
if((a==b)&(b==c)):
  print("three numbers are equal")
elif((a==b)or(a==c)):
     print("two numbers are equal")
elif((b==a)or(b==c)):
      print("two numbers are equal")    
else:
      print("not equal")
# Out:
# enter a1
# enter b2
# enter c1
# two numbers are equal
